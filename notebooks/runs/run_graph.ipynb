# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/icail
# Out:
# /content/drive/MyDrive/icail

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda create -n py310 python=3.10 -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 26.3.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/py310
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |           20_gnu          28 KB  conda-forge
#     bzip2-1.0.8                |       hda65f42_9         254 KB  conda-forge
#     ca-certificates-2026.4.22  |       hbd8a1cb_0         128 KB  conda-forge
#     icu-78.3                   |       h33c6efd_0        12.1 MB  conda-forge
#     ld_impl_linux-64-2.45.1    |default_hbd61a6d_102         711 KB  conda-forge
# ...

# %%
# Xóa sạch để tránh conflict
# !conda run -n py310 pip uninstall -y torch torchvision torchaudio torch-geometric transformers sentence-transformers accelerate numpy

# Cài lại đúng stack
# !conda run -n py310 pip install torch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2

# !conda run -n py310 pip install torch-geometric==2.4.0

# !conda run -n py310 pip install numpy==1.26.4

# !conda run -n py310 pip install sentence-transformers==5.1.0
# !conda run -n py310 pip install transformers==4.41.2
# !conda run -n py310 pip install tokenizers==0.19.1
# !conda run -n py310 pip install accelerate==0.21.0

# !conda run -n py310 pip install huggingface-hub==0.23.4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 32.4 MB/s  0:00:09
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 109.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 95.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 48.1 MB/s  0:00:06
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 162.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 164.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 56.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 30.9 MB/s  0:00:10
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 111.2 MB/s  0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 128.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 60.5 MB/s  0:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 108.5 MB/s  0:00:01
# ...

# %%
# !bash -c "source activate py310 && cd /content/drive/MyDrive/icail && python graphs/main_train_graphsage.py"
# Out:
# CUDA available: True
# Device: cuda
# Num articles: 782
# Num edges: 3466
# Internal edges: 2904
# External edges: 341
# Num training triples: 2034
# You are trying to use a model that was created with Sentence Transformers version 5.3.0, but you're currently using version 5.1.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
# Encoding articles...
# Encoding queries...
# Epoch 0 Loss: 1.8664
# [Epoch 0] Loss=1.8664 | Triplet=0.3901 | Edge=1.0169 | Pos=0.6119 | Neg=0.4558 | EdgeSimIn=0.9224 | EdgeSimEx=0.8702 | Alpha=0.5000 | Beta=0.5000
# alpha grad: tensor(0., device='cuda:0')
# beta grad: None
# Epoch 1 Loss: 1.8648
# [Epoch 1] Loss=1.8648 | Triplet=0.3896 | Edge=1.0163 | Pos=0.5698 | Neg=0.4849 | EdgeSimIn=0.9224 | EdgeSimEx=0.8702 | Alpha=0.5000 | Beta=0.5000
# alpha grad: tensor(0., device='cuda:0')
# beta grad: None
# Epoch 2 Loss: 1.8597
# ...

# %%
# !bash -c "source activate py310 && cd /content/drive/MyDrive/icail && python graphs/infer_new.py"
# Out:
# Loading BGE model...
# You are trying to use a model that was created with Sentence Transformers version 5.3.0, but you're currently using version 5.1.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
# Preparing graph...
# Num articles: 782
# Num edges: 3466
# Encoding articles with BGE...
# Loading GraphSAGE...
# Running GraphSAGE forward...
# Loading queries...
# Encoding queries...
# Retrieving...
